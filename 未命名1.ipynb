# %%
import types


def function():
    return 1


def generator():
    yield 1


async def async_function():
    return 1


async def async_generator():
    yield 1


print(type(function) is types.FunctionType)
print(type(generator()) is types.GeneratorType)
print(type(async_function()) is types.CoroutineType)
print(type(async_generator()) is types.AsyncGeneratorType)
print(async_function())
# Out:
# True
# True
# True
# True
# <coroutine object async_function at 0x10cc155c0>
# <ipython-input-1-b86eb69f6637>:22: RuntimeWarning: coroutine 'async_function' was never awaited
#   print(type(async_function()) is types.CoroutineType)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# <ipython-input-1-b86eb69f6637>:24: RuntimeWarning: coroutine 'async_function' was never awaited
#   print(async_function())
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
import time
import asyncio


async def non_asyn_sleep(i):
    time.sleep(1)
    print("Synchonous coroutine {} sleeps 1s".format(i))


async def asyn_sleep(i):
    await asyncio.sleep(1)
    print("asynchonous coroutine {} sleep 1s".format(i))


def supervisor(f):
    t0 = time.time()
    futures = [f(i) for i in range(5)]
    wait_list = asyncio.wait(futures)
    loop = asyncio.get_event_loop()
    loop.run_until_complete(wait_list)
    print("Time Elapsed: {:.3}s\n".format(time.time() - t0))


if __name__ == "__main__":
    supervisor(non_asyn_sleep)
    supervisor(asyn_sleep)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-250971345e73> in <module>
#      23
#      24 if __name__ == "__main__":
# ---> 25     supervisor(non_asyn_sleep)
#      26     supervisor(asyn_sleep)
#
# <ipython-input-2-250971345e73> in supervisor(f)
#      18     wait_list = asyncio.wait(futures)
#      19     loop = asyncio.get_event_loop()
# ---> 20     loop.run_until_complete(wait_list)
#      21     print("Time Elapsed: {:.3}s\n".format(time.time() - t0))
#      22
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/asyncio/base_events.py in run_until_complete(self, future)
#     593         future.add_done_callback(_run_until_complete_cb)
#     594         try:
# --> 595             self.run_forever()
#     596         except:
#     597             if new_task and future.done() and not future.cancelled():
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/asyncio/base_events.py in run_forever(self)
#     548         self._check_closed()
#     549         if self.is_running():
# --> 550             raise RuntimeError('This event loop is already running')
#     551         if events._get_running_loop() is not None:
#     552             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# Synchonous coroutine 4 sleeps 1s
# Synchonous coroutine 2 sleeps 1s
# Synchonous coroutine 1 sleeps 1s
# Synchonous coroutine 0 sleeps 1s
# Synchonous coroutine 3 sleeps 1s
